# %%
#IMPORTING LIBRARIES

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#LOADING DATASET

dataset = pd.read_csv('data.csv')

# %%
dataset.head()
# Out:
#    Unnamed: 0        id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0           0    842302         M        17.99         10.38          122.80
# 1           1    842517         M        20.57         17.77          132.90
# 2           2  84300903         M        19.69         21.25          130.00
# 3           3  84348301         M        11.42         20.38           77.58
# 4           4  84358402         M        20.29         14.34          135.10
#
#    area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0     1001.0          0.11840           0.27760          0.3001
# 1     1326.0          0.08474           0.07864          0.0869
# 2     1203.0          0.10960           0.15990          0.1974
# 3      386.1          0.14250           0.28390          0.2414
# 4     1297.0          0.10030           0.13280          0.1980
#
#             ...             radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
dataset.describe()
# Out:
#        Unnamed: 0            id  radius_mean  texture_mean  perimeter_mean  \
# count  569.000000  5.690000e+02   569.000000    569.000000      569.000000
# mean   284.000000  3.037183e+07    14.127292     19.289649       91.969033
# std    164.400426  1.250206e+08     3.524049      4.301036       24.298981
# min      0.000000  8.670000e+03     6.981000      9.710000       43.790000
# 25%    142.000000  8.692180e+05    11.700000     16.170000       75.170000
# 50%    284.000000  9.060240e+05    13.370000     18.840000       86.240000
# 75%    426.000000  8.813129e+06    15.780000     21.800000      104.100000
# max    568.000000  9.113205e+08    28.110000     39.280000      188.500000
#
#          area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# count   569.000000       569.000000        569.000000      569.000000
# mean    654.889104         0.096360          0.104341        0.088799
# std     351.914129         0.014064          0.052813        0.079720
# ...

# %%
#A HEATMAP GIVES CORRELATION BETWEEN ATTRIBUTES OF DATASET WITH ONE ANOTHER.
plt.subplots(figsize=(50,50))
sns.heatmap(dataset.corr(),annot=True)

# %%
#STANDARD SCALER MAKES MEAN = 0 AND STANDARD DEVIATION = 1

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = dataset.iloc[:,3:]

# %%
scaler.fit(x)
scaled_features = (scaler.transform(dataset.iloc[:,3:]))

# %%
#DATA IS CONVERTED TO ANOTHER DATAFRAME
df = pd.DataFrame(scaled_features, columns=dataset.columns[3:])

# %%
df.describe()
# Out:
#         radius_mean  texture_mean  perimeter_mean     area_mean  \
# count  5.690000e+02  5.690000e+02    5.690000e+02  5.690000e+02
# mean  -1.256562e-16  1.049736e-16   -1.272171e-16 -1.900452e-16
# std    1.000880e+00  1.000880e+00    1.000880e+00  1.000880e+00
# min   -2.029648e+00 -2.229249e+00   -1.984504e+00 -1.454443e+00
# 25%   -6.893853e-01 -7.259631e-01   -6.919555e-01 -6.671955e-01
# 50%   -2.150816e-01 -1.046362e-01   -2.359800e-01 -2.951869e-01
# 75%    4.693926e-01  5.841756e-01    4.996769e-01  3.635073e-01
# max    3.971288e+00  4.651889e+00    3.976130e+00  5.250529e+00
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count     5.690000e+02      5.690000e+02    5.690000e+02         5.690000e+02
# mean      1.045834e-16      2.528733e-16   -1.088760e-16        -5.619407e-17
# std       1.000880e+00      1.000880e+00    1.000880e+00         1.000880e+00
# ...

# %%
from sklearn.model_selection import train_test_split

xtrain,xtest,ytrain,ytest = train_test_split(df, dataset['diagnosis'],test_size=0.2, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

knc = KNeighborsClassifier(n_neighbors=10)
knc.fit(xtrain,ytrain)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=10, p=2,
#            weights='uniform')

# %%
predictions = knc.predict(xtest)

# %%
#CALUCULATING ERROR IN MODEL
from sklearn.metrics import mean_squared_error
mean_squared_error(pd.get_dummies(ytest), pd.get_dummies(predictions))
# Out:
# 0.043859649122807015

# %%
knc.score(xtest,ytest)
# Out:
# 0.956140350877193
